# %% [markdown]
# <a href="https://colab.research.google.com/github/41123222009/2024101471-Data_Mining-PreProcessing_Data/blob/main/Latihan%7CPreProcessing_Data%7CData_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Latihan Pre Processing Data | Data Mining**
# Iksan Nur Afiah - 41123322009

# %% [markdown]
# ## **1. Memuat Data**
# Langkah pertama adalah mengimport library yang akan digunakan untuk analisis data. Serta, memuat data dari file CSV ke dalam Data Frame.

# %%
import pandas as pd
import numpy as np

# Memuat data dari file CSV
df = pd.read_csv('https://raw.githubusercontent.com/41123222009/2024101471-Data_Mining-PreProcessing_Data/refs/heads/main/movie_dataset_cleaned.csv')

# %% [markdown]
# ## **2. Memeriksa Data**
# Menampilkan beberapa baris pertama dari dataset untuk memahami struktur data.

# %%
df
# Out:
#     color      director_name  duration      gross  \
# 0   Color    Martin Scorsese       240  116866727
# 1   Color        Shane Black       195  408992272
# 2   Color  Quentin Tarantino       187   54116191
# 3   Color   Kenneth Lonergan       186      46495
# 4   Color      Peter Jackson       186  258355354
# ..    ...                ...       ...        ...
# 60  Color        Tony Gilroy       135  113165635
# 61  Color      Steve Mcqueen       134   56667870
# 62  Color    Paul Greengrass       134  107100855
# 63  Color         David Ayer       134   85707116
# 64  Color     Clint Eastwood         5   47034272
#
#                                       genres  \
# 0            Biography, Comedy, Crime, Drama
# 1                  Action, Adventure, Sci-Fi
# 2   Crime, Drama, Mystery, Thriller, Western
# 3                                      Drama
# 4                         Adventure, Fantasy
# ..                                       ...
# 60               Action, Adventure, Thriller
# 61                 Biography, Drama, History
# 62                Biography, Drama, Thriller
# 63                        Action, Drama, War
# 64          Biography, Drama, Music, Musical
#
#                             movie_title  title_year language country  \
# 0               The Wolf Of Wall Street        2013  English     USA
# 1                            Iron Man 3        2013  English     USA
# 2                     The Hateful Eight        2015  English     USA
# 3                              Margaret        2011  English     USA
# 4   The Hobbit: The Desolation Of Smaug        2013  English     USA
# ..                                  ...         ...      ...     ...
# 60                    The Bourne Legacy        2012  English     USA
# 61                     12 Years A Slave        2013  English     USA
# 62                     Captain Phillips        2013  English     USA
# 63                                 Fury        2014  English     USA
# 64                          Jersey Boys        2014  English     USA
#
#        budget  imdb_score                                             actors  \
# 0   100000000         8.2  Leonardo DiCaprio, Matthew McConaughey, Jon Fa...
# 1   200000000         7.2        Robert Downey Jr., Jon Favreau, Don Cheadle
# 2    44000000         7.9        Craig Stark, Jennifer Jason Leigh, Zoë Bell
# 3    14000000         6.5      Matt Damon, Kieran Culkin, John Gallagher Jr.
# 4   225000000         7.9            Aidan Turner, Adam Brown, James Nesbitt
# ..        ...         ...                                                ...
# 60  125000000         6.7            Jeremy Renner, Scott Glenn, Stacy Keach
# 61   20000000         8.1     Quvenzhané Wallis, Scoot McNairy, Taran Killam
# 62   55000000         7.9           Tom Hanks, Chris Mulkey, Michael Chernus
# 63   68000000         7.6               Brad Pitt, Logan Lerman, Jim Parrack
# 64   40000000         6.9    Johnny Cannizzaro, Steve Schirripa, Scott Vance
#
#     movie_facebook_likes
# 0                 138000
# 1                  95000
# 2                 114000
# 3                      0
# 4                  83000
# ..                   ...
# 60                 31000
# 61                 83000
# 62                 65000
# 63                 82000
# 64                 16000
#
# [65 rows x 13 columns]

# %% [markdown]
# Memeriksa beberapa informasi umum tentang dataset yaitu:
# * Tipe data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   color                 65 non-null     object
#  1   director_name         65 non-null     object
#  2   duration              65 non-null     int64
#  3   gross                 65 non-null     int64
#  4   genres                65 non-null     object
#  5   movie_title           65 non-null     object
#  6   title_year            65 non-null     int64
#  7   language              65 non-null     object
#  8   country               65 non-null     object
#  9   budget                65 non-null     int64
#  10  imdb_score            65 non-null     float64
#  11  actors                65 non-null     object
#  12  movie_facebook_likes  65 non-null     int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 6.7+ KB

# %% [markdown]
# * Nilai yang hilang

# %%
# Mengganti '?' dengan NaN
df.replace('?', np.nan, inplace=True)

# Memeriksa jumlah missing values di setiap kolom
print(df.isnull().sum())
# Out:
# color                   0
# director_name           0
# duration                0
# gross                   0
# genres                  0
# movie_title             0
# title_year              0
# language                0
# country                 0
# budget                  0
# imdb_score              0
# actors                  0
# movie_facebook_likes    0
# dtype: int64

# %% [markdown]
# ## **3. Membersihkan Data**
#
# * Menghapus baris yang memiliki nilai NaN di kolom penting seperti gross dan budget.

# %%
# Menghapus baris dengan missing values pada kolom 'gross' dan 'budget'
df.dropna(subset=['gross', 'budget'], axis=0, inplace=True)

# Reset index setelah menghapus baris
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# * Mengatasi nilai yang tidak konsisten atau kesalahan penulisan di kolom.

# %%
# Mengatasi kesalahan penulisan pada beberapa kolom
df.loc[:, 'color'] = df['color'].str.strip().str.capitalize()
df['director_name'] = df['director_name'].str.title()
df['movie_title'] = df['movie_title'].str.title()
df['language'] = df['language'].str.title()

# Mengatasi ketidak konsistenan penulisan pada beberapa kolom
df['country'] = df['country'].replace(['usa', 'United States'], 'USA')
df['title_year'] = df['title_year'].replace(205, 2005)

# %% [markdown]
# * Mengubah dan menghapus nilai-nilai yang tidak standar, seperti nilai negatif atau 'N/A't

# %%
# Memfilter DataFrame agar hanya menampilkan nilai yang lebih besar atau sama dengan 0
df = df[(df['duration'] >= 0) &
        (df['title_year'] >= 0) &
        (df['imdb_score'] >= 0) &
        (df['movie_facebook_likes'] >=0 )]

# Mengubah nilai yang tidak standar menjadi nilai kosong
df = df.replace(['N/A', 'Null', 'Nan'], np.nan)

# Menghapus baris dengan nilai kosong
df.dropna(axis=0, inplace=True)

# Reset index setelah menghapus baris
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## **4. Transformasi Data**
# * Mengubah tipe data kolom menjadi tipe data yang sesuai

# %%
df[['gross', 'budget']] = df[['gross','budget']].astype(int)

# %% [markdown]
# * Menormalisasi teks untuk memastikan konsistensi

# %%
df['actors'] = df['actors'].str.replace(',', ', ', regex=False)
df['genres'] = df['genres'].str.replace('|', ', ', regex=False)

# %% [markdown]
# ## **5. Penyimpanan data**
# Menyimpan data yang telah diproses ke dalam file CSV baru

# %%
df.to_csv('movie_dataset_cleaned.csv', index=False)
